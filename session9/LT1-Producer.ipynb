# %% [markdown]
# <a class="anchor" id="lab-task-1"></a>
# <div style="background:rgba(0,109,174,0.2);padding:10px;border-radius:4px"><strong style="color:#FF5555">1. Lab Task: </strong>
#     <ol>
#         <li>Complete the <strong>Kafka Producer</strong> in the file <code>LT1-Producer.ipynb</code>. Here you are required to address the following conditions:
#     <ul>
#         <li>Read the data frome the csv file <code>clickstream.csv</code> continiously.</li>
#         <li>Add the current timestamp to the data being sent</li>
#         <li>Publish <strong>5-10</strong> number of rows randomly every <strong>5 seconds</strong> to a topic named:<strong>clickstream</strong>.</li>
#     </ul>
#     </ol>
# </div>

# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import csv


def read_csv(fileName):
    '''Read the CSV file clickstream.csv'''
    '''you can use csv.DictReader'''
     #WRITE THE CODE TO READ CSV FILE
    data = []
    with open(fileName, 'r') as f:
        for row in csv.DictReader(f):
            data.append(row)
    
    return data

def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, data)
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'clickstream'
    cRows = read_csv('clickstream.csv')
    
    print('Publishing records..')
    producer = connect_kafka_producer()

    
    
    #WRITE THE CODE HERE
    #A while True loop to infinitely loop through records
    #A random function to get random number of rows between 5-10 use random.randint(5,10)
    #Create the data object to publish with the selected rows, also include the current timestamp as ts
    #Sleep for 5 seconds    
    while True:
        rand = random.randint(5,10)
        record = random.sample(cRows, rand)
        ts = dt.datetime.now().timestamp()
        data = {'ts':ts, 'data':record}
#       publish_message(producer, topic, dumps(date))
        publish_message(producer, topic, data)
        sleep(5)
# Out:
# Publishing records..
# Message published successfully. Data: {'ts': 1612246994.958316, 'data': [{'Age': '45', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247000.008154, 'data': [{'Age': '32', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '23', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247005.012584, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '0', 'Impressions': '3', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247010.015773, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '38', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '64', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '75', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247015.018675, 'data': [{'Age': '74', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '67', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247020.024089, 'data': [{'Age': '39', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '75', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '16', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '71', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '51', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '66', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247025.031519, 'data': [{'Age': '19', 'Gender': '1', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '63', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '25', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '40', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '51', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247030.035612, 'data': [{'Age': '61', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '75', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '33', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '44', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '80', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247035.042539, 'data': [{'Age': '40', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '72', 'Gender': '0', 'Impressions': '3', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '21', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '36', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247040.046618, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '34', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247045.050535, 'data': [{'Age': '40', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '43', 'Gender': '1', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '61', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '22', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247050.055669, 'data': [{'Age': '30', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '23', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '31', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '30', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '18', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '61', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247055.058677, 'data': [{'Age': '36', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '72', 'Gender': '1', 'Impressions': '7', 'Clicks': '2', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '57', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '50', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612
 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247260.254843, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '22', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '69', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '17', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247265.257511, 'data': [{'Age': '85', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '39', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247270.263397, 'data': [{'Age': '57', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '1', 'Impressions': '7', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '29', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '62', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '27', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '26', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247275.268077, 'data': [{'Age': '44', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '1', 'Impressions': '8', 'Clicks': '2', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '17', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '49', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '50', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247280.274933, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '54', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '52', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247285.278824, 'data': [{'Age': '16', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '59', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '75', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247290.282936, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '24', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '33', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247295.29571, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '18', 'Gender': '1', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '33', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '33', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '18', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247300.304173, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '20', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '59', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '58', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247305.306729, 'data': [{'Age': '37', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '56', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '61', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '58', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247310.311133, 'data': [{'Age': '59', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '52', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '55', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '44', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '79', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '35', 'Gender': '1', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '52', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247315.316661, 'data': [{'Age': '21', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '33', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '75', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '54', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '56', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '45', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247320.322622, 'data': [{'Age': '56', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '40', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '46', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247325.337123, 'data': [{'Age': '51', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '37', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '48', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247330.34263, 'data': [{'Age': '21', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '72', 'Gender': '1', 'Impressions': '2', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '56', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '10', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '10', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '39', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '10', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '27', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247335.346618, 'data': [{'Age': '48', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '40', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '37', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '61', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '80', 'Gender': '1', 'Impressions': '5', 'Clicks': '2', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247340.349025, 'data': [{'Age': '28', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '41', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '37', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247345.354935, 'data': [{'Age': '29', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '29', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '60', 'Gender': '1', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247350.361183, 'data': [{'Age': '60', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '29', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '37', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '38', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '66', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247355.366687, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '21', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '19', 'Gender': '0', 'Impressions': '9', 'Clicks': '1', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247360.370594, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '58', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '33', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '71', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '25', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247365.376337, 'data': [{'Age': '51', 'Gender': '1', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '38', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '17', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '53', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '31', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247370.378672, 'data': [{'Age': '32', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '59', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '0', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '63', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247375.383562, 'data': [{'Age': '36', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '66', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '16', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '58', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '28', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '33', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247380.390688, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '32', 'Gender': '1', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '54', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '31', 'Gender': '0', 'Impressions': '3', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '78', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '4', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '20', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247385.394608, 'data': [{'Age': '80', 'Gender': '0', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '41', 'Gender': '1', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '28', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '47', 'Gender': '1', 'Impressions': '6', 'Clicks': '1', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247390.398633, 'data': [{'Age': '70', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '20', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '11', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '60', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247395.40807, 'data': [{'Age': '39', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '44', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '34', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247400.418267, 'data': [{'Age': '56', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '46', 'Gender': '1', 'Impressions': '8', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '76', 'Gender': '1', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '68', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '27', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '19', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '32', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247405.439552, 'data': [{'Age': '21', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '18', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '42', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '28', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '36', 'Gender': '0', 'Impressions': '2', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '0', 'Gender': '0', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '0'}]}
# Message published successfully. Data: {'ts': 1612247410.454597, 'data': [{'Age': '57', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '29', 'Gender': '0', 'Impressions': '3', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '62', 'Gender': '0', 'Impressions': '6', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '43', 'Gender': '1', 'Impressions': '4', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '46', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '62', 'Gender': '0', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '57', 'Gender': '0', 'Impressions': '9', 'Clicks': '0', 'Signed_In': '1'}]}
# Message published successfully. Data: {'ts': 1612247415.467697, 'data': [{'Age': '0', 'Gender': '0', 'Impressions': '7', 'Clicks': '0', 'Signed_In': '0'}, {'Age': '62', 'Gender': '0', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '24', 'Gender': '1', 'Impressions': '5', 'Clicks': '0', 'Signed_In': '1'}, {'Age': '0', 'Gender': '0', 'Impressions': '5', 'Clicks': '1', 'Signed_In': '0'}, {'Age': '47', 'Gender': '1', 'Impressions': '1', 'Clicks': '0', 'Signed_In': '1'}]}

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import csv


def read_csv(fileName):
    '''Read the CSV file clickstream.csv'''
    '''you can use csv.DictReader'''
     #WRITE THE CODE TO READ CSV FILE
    data = []
    with open(fileName, 'r') as f:
        for row in csv.DictReader(f):
            data.append(row)
    return data


cRows = read_csv('clickstream.csv')

# %%
cRows
